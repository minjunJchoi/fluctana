# %% [markdown]
# ### Example #2
#
# Author : Minjun J. Choi (mjchoi@nfri.re.kr)
#
# We will calculate coherence mean image similar with Fig.6 in Choi NF 2017
# <img src="files/16150_coh.png">

# %%
# %matplotlib inline 
import sys, os
sys.path.append(os.pardir)
from fluctana import *
# Out:
# /usr/local/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
A = FluctAna()
A.add_data(dev='KSTAR', shot=16150, clist=['ECEI_G0101-2308'], trange=[7.57, 7.62])
A.add_data(dev='KSTAR', shot=16150, clist=['ECEI_G0201-2408'], trange=[7.57, 7.62])
# Out:
# ECEI file = /eceidata2/exp_2016/016150/ECEI.016150.GFS.h5
# Data is normalized by trange average ECEI
# SAT offset data  channel ECEI_G0905, offstd = 4.44089e-16%, offlevel = -2.5723 V
# LOW signal level channel ECEI_G1301, ref = 100%, siglevel = 0.0001 V
# LOW signal level channel ECEI_G1302, ref = 100%, siglevel = 0.0009 V
# LOW signal level channel ECEI_G1303, ref = 754.617%, siglevel = 0.0161 V
# LOW signal level channel ECEI_G1304, ref = 435.641%, siglevel = 0.0335 V
# LOW signal level channel ECEI_G1305, ref = 100%, siglevel = -0.0186 V
# LOW signal level channel ECEI_G1306, ref = 100%, siglevel = -0.1424 V
# LOW signal level channel ECEI_G1307, ref = 246.693%, siglevel = 0.0269 V
# LOW signal level channel ECEI_G1308, ref = 199.347%, siglevel = 0.017 V
# ECEI file = /eceidata2/exp_2016/016150/ECEI.016150.GFS.h5
# Data is normalized by trange average ECEI
# SAT offset data  channel ECEI_G0905, offstd = 4.44089e-16%, offlevel = -2.5723 V
# ...

# %%
A.fftbins(nfft=512,window='hann',overlap=0.5,detrend=1)
# Out:
# dnum 0 fftbins 193 with hann size 512 overlap 0.5 detrend 1 full 0
# dnum 1 fftbins 193 with hann size 512 overlap 0.5 detrend 1 full 0

# %%
A.coherence(done=0,dtwo=1)

# %%
A.cplot(dnum=1,snum=124,frange=[0,60],vlimits=[0,0.4])
